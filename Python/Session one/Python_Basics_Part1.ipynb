# %% [markdown]
# # Python Basics Part one Notebook

# %% [markdown]
# ## Comments

# %%
# This is a single-line comment

# %%
# Multiple single-line comments
# This line does nothing
# This is also a comment

# one 
# two

# %%
"""
This is a multi-line comment
also called docstring
"""
# Out:
# '\nThis is a multi-line comment\nalso called docstring\n'

# %%
print()

if True:
    print("True")

# %% [markdown]
# ### Exercise: Add a comment and print your name

# %%
# Write your code here

# %%
# Solution
# This prints my name

# %% [markdown]
# ## Print Function

# %%
print("Hello")

print("hi")
# Out:
# Hello
# hi

# %%
print("Hello", "Python", 2026)
# Out:
# Hello Python 2026

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello", end=" ")
print("World")
# Out:
# Hello World

# %%
name = "Ali"
age = 20
print("Name:", name)
print("Age:", age)
# Out:
# Name: Ali
# Age: 20

# %% [markdown]
# ### Exercise: Print your name, age, and country

# %%
# Write your code here

# %%
# Solution
print("Name:", "Ahmed")
print("Age:", 25)
print("Country:", "Egypt")

# %% [markdown]
# ## Variables

# %%
x = 10
x = 5
print(x)
# Out:
# 5

# %%
x = "khaled"

# %%
x = 10
print(x)
# Out:
# 10

# %%
name = "Python"
print(name)
# Out:
# Python

# %%
# Changing variable value
x = 10
x = 20
print(x)
# Out:
# 20

# %%
# Multiple variables
a, b, c = 1, 2, 3
print(a, b, c)
# Out:
# 1 2 3

# %%
# Same value to multiple variables
omar = john = ali = 5000
print("omar : ",omar , "john : ", john , "ali : ",ali)
# Out:
# omar :  5000 john :  5000 ali :  5000

# %%
# Dynamic typing
x = 10
print(x)

x = "Python"
print(x)
# Out:
# 10
# Python

# %% [markdown]
# ### Exercise: Create 3 variables and print them

# %%
# Write your code here

# %%
# Solution
name = "Sara"
age = 22
country = "USA"
print(name, age, country)

# %%
age105180 = 10
print(age105180)

FirstName ="omar"
first_name = "Ali"

NAME = "khaled"
# Out:
# 10

# %% [markdown]
# ## Data Types

# %%
# Integer
x = 10
print(x, type(x))
# Out:
# 10 <class 'int'>

# %%
# Float
x = 3.14
salary = 1000.50
print(salary, type(salary))
# Out:
# 1000.5 <class 'float'>

# %%
print(salary+x)
# Out:
# 1003.64

# %%
# String
x = "Python"
print(x, type(x))
# Out:
# Python <class 'str'>

# %%
# Bytes
x = bytes([65, 66, 67]) #ABC
print(x, type(x))
# Out:
# b'ABC' <class 'bytes'>

# %%
# Boolean
x = True
print(x, type(x))
# Out:
# True <class 'bool'>

# %%
# List
x = [1, 2, 3]
print(x, type(x))
# Out:
# [1, 2, 3] <class 'list'>

# %%
# Tuple
x = (1, 2, 3)
print(x, type(x))
# Out:
# (1, 2, 3) <class 'tuple'>

# %%
# Dictionary
x = {"name": "Ali", "age": 25}
print(x, type(x))
# Out:
# {'name': 'Ali', 'age': 25} <class 'dict'>

# %%
# Set
x = {1, 2, 3}
print(x, type(x))
# Out:
# {1, 2, 3} <class 'set'>

# %% [markdown]
# ### Exercise: Create one variable of each type

# %%
# Write your code here

# %%
# Solution
a = 10
b = 3.5
c = "Hello"
d = True
e = [1,2,3]
f = (1,2,3)
g = {"key":"value"}
h = {1,2,3}
i = bytes([65,66])

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(type(h))
print(type(i))

# %% [markdown]
# ## Final Exercises

# %%
# Exercise 1: Create variable reminding your name and print it

# %%
# Exercise 2: Print numbers from 1 to 5

# %%
# Exercise 3: Create integer, float, string, boolean variables and print their types

# %%
# Solutions

# Exercise 1
name = "Ahmed"
print(name)

# Exercise 2
print(1,2,3,4,5)

# Exercise 3
a = 10
b = 3.14
c = "Python"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
